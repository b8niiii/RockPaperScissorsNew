# %% [markdown]
# From running CNN1 we found that the following are the best parameters: Best config: {'out_channels': 16, 'conv_kernel_size': 7, 'pool_kernel_size': 2, 'lr': 0.0005115859153484923, 'batch_size': 16}. NB: these were the results of the CNN1 model when I first ran it, then I set the seed = 42 and ran it again after having completed this model, so the aforementioned results refer to another instance.
#
# Since we will not fine tune them this time, we will use the aforementioned ones and will focus on a more complex architecture:

# %%
import torch 
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Subset, ConcatDataset
import os 
import random
import numpy as np
import json, re
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
import torch.optim as optim # for PyTorch optimizers
import math
import pandas as pd
from torchvision import transforms, datasets 
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

SEED = 42

# Python and NumPy
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)

# PyTorch
torch.manual_seed(SEED)


# Apple Silicon (MPS) - safe to call regardless of MPS availability
if hasattr(torch, "mps") and torch.backends.mps.is_available():
    torch.manual_seed(SEED)

# Deterministic behavior (may reduce speed; some ops may still be nondeterministic)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False



class MediumCNN(nn.Module):
    def __init__(self, num_classes = 3):
        super().__init__()

        self.features = nn.Sequential(
            nn.Conv2d(in_channels = 3, out_channels = 16, kernel_size = 7, padding = 7 // 2, stride =1 ), # 7//2 = 3 padding to keep the same spatial size of the input and output (same convolution)
            nn.BatchNorm2d(16), # normalizes activations inside the net, channel after channel. Makes training quicker and more efficient. Brings mean to zero and variance to 1
            nn.ReLU(), # breaks the linearity
            nn.MaxPool2d(2), # Pool layer that returns the highest value for each 2x2 spatial region (kernel = 2 and by default stride = kernel, so number of spatial position is 4 times smaller)
            
            nn.Conv2d(in_channels= 16, out_channels = 32, kernel_size = 3, padding = 1 ), 
            nn.BatchNorm2d(32), 
            nn.ReLU(), 
            nn.MaxPool2d(2)
            
            ) 
        self.classifier = nn.Sequential(
            nn.LazyLinear(128), # lazy layer that outputs 128 units where you do not have to specify the number of in_features upfront.
            nn.ReLU(), 
            nn.Dropout(0.5), 
            nn.Linear(128, num_classes)
        )
        

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1) # flatten all dimensions except batch dimension (dim=0)
        x = self.classifier(x)
        return x

# %%
# Load datasets locally in the training function

img_size = (256, 256)
train_transform = transforms.Compose([
    transforms.Resize(img_size),
    transforms.RandomHorizontalFlip(p = 0.5),
    transforms.RandomRotation(degrees= 15),
    transforms.ColorJitter(
        brightness = 0.2,
        saturation = 0.2,
        contrast = 0.2,
        hue = 0.1,
    ),
    transforms.ToTensor(),
    transforms.Normalize(mean = [0.5, 0.5, 0.5],std = [0.5,0.5,0.5])
])


test_transform = transforms.Compose([
    transforms.Resize(img_size),
    transforms.ToTensor(),
    transforms.Normalize(mean = [0.5, 0.5, 0.5],std = [0.5,0.5,0.5])
])


train_ds_local = datasets.ImageFolder("/Users/alessandro/Progetti/RockPaperScissorNew/rps-split/train", transform=train_transform)
val_ds_local = datasets.ImageFolder("/Users/alessandro/Progetti/RockPaperScissorNew/rps-split/val", transform=train_transform)
full_ds = ConcatDataset([train_ds_local, val_ds_local])


kf = KFold(n_splits=10, shuffle=True, random_state=42) 
indices = np.arange(len(full_ds)) #indices array to make KFold work with concatenated dataset

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

history = {
    "fold": [],
    "epoch": [],
    "train_loss": [],
    "train_acc": [],
    "val_loss": [],
    "val_acc": [],
}

fold_summary = []  # one row per fold (e.g., best/last metrics)

for fold, (train_idx, val_idx) in enumerate(kf.split(indices)): 
    print(f'Fold {fold + 1}')
    train_subset = Subset(full_ds, train_idx)
    val_subset   = Subset(full_ds, val_idx)

    cnn = MediumCNN()
    cnn = cnn.to(device) # moves model parameters (weights and biases) to the target device


    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(cnn.parameters(), lr = 0.0005115859153484923, momentum = 0.9)

    trainloader = torch.utils.data.DataLoader(
        train_subset,
        batch_size = 16,
        shuffle = True, # shuffle the training data at every epoch to help the model generalize better and avoid overfitting to the order of the data
        num_workers = 2,
    )
    valloader = torch.utils.data.DataLoader(
        val_subset,
        batch_size = 16,
        shuffle = False,
        num_workers = 2,
    )

    best_val_loss = math.inf
    best_val_acc = 0.0
    

    for epoch in range(20):

        print(f'Training epoch {epoch}...')
        cnn.train() # enables dropout and batchnorm
        running_loss = 0.0
        train_correct = 0
        train_total = 0

        n_train = 0

        for inputs, labels in trainloader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad() # zeroes the gradients of all model parameters before computing the gradients for the current batch
            outputs = cnn(inputs)
            preds = outputs.argmax(dim=1) # get the predicted class index (the one with the highest logit) for each sample in the batch
            train_correct += (preds == labels).sum().item()
            train_total += labels.size(0)

            loss = criterion(outputs, labels)
            loss.backward() # computes gradients of the loss w.r.t. model parameters
            optimizer.step() # updates model parameters using the computed gradients and the learning rate

            running_loss += loss.item() * labels.size(0)
            n_train += labels.size(0)

        train_loss = running_loss / max(n_train, 1) # average loss per sample in the epoch, avoid division by zero
        train_acc  = train_correct / max(train_total, 1) 


        print(f'Loss = {round(train_loss, 4)}, Accuracy = {round(train_acc, 4)}')

        cnn.eval()
        val_loss = 0.0
        total = 0
        correct = 0

        with torch.no_grad():
            for inputs, labels in valloader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = cnn(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * labels.size(0)
                preds = outputs.argmax(dim=1)
                correct += (preds == labels).sum().item()
                total += labels.size(0)

        val_loss = val_loss / max(total, 1)
        val_acc = correct / max(total, 1)

        if val_loss < best_val_loss:
            best_val_loss = val_loss

        if val_acc > best_val_acc:
            best_val_acc = val_acc
    # Save metrics for the current epoch in the history log
        history["fold"].append(fold + 1)
        history["epoch"].append(epoch + 1)
        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)

        print(f'Validation accuracy: {val_acc}')

# After all epochs of the current fold, save the best and last metrics for the fold summary
    fold_summary.append({
    "fold": fold + 1,
    "best_val_loss": best_val_loss,
    "best_val_acc": best_val_acc,
    "last_val_loss": val_loss,
    "last_val_acc": val_acc,
        })
# Out:
# Fold 1
# Training epoch 0...
# Loss = 1.0568, Accuracy = 0.465
# Validation accuracy: 0.6935483870967742
# Training epoch 1...
# Loss = 0.8137, Accuracy = 0.6272
# Validation accuracy: 0.8118279569892473
# Training epoch 2...
# Loss = 0.702, Accuracy = 0.675
# Validation accuracy: 0.8548387096774194
# Training epoch 3...
# Loss = 0.6482, Accuracy = 0.7068
# Validation accuracy: 0.8602150537634409
# Training epoch 4...
# Loss = 0.5356, Accuracy = 0.772
# Validation accuracy: 0.9354838709677419
# Training epoch 5...
# Loss = 0.4845, Accuracy = 0.7959
# Validation accuracy: 0.9086021505376344
# Training epoch 6...
# Loss = 0.464, Accuracy = 0.8001
# Validation accuracy: 0.8655913978494624
# Training epoch 7...
# Loss = 0.4335, Accuracy = 0.8127
# Validation accuracy: 0.9247311827956989
# Training epoch 8...
# Loss = 0.4128, Accuracy = 0.8259
# Validation accuracy: 0.9408602150537635
# Training epoch 9...
# Loss = 0.4326, Accuracy = 0.8223
# Validation accuracy: 0.9247311827956989
# Training epoch 10...
# Loss = 0.3707, Accuracy = 0.842
# Validation accuracy: 0.9247311827956989
# Training epoch 11...
# Loss = 0.3478, Accuracy = 0.8486
# Validation accuracy: 0.946236559139785
# Training epoch 12...
# Loss = 0.332, Accuracy = 0.8546
# Validation accuracy: 0.9408602150537635
# Training epoch 13...
# Loss = 0.3955, Accuracy = 0.8498
# Validation accuracy: 0.9408602150537635
# Training epoch 14...
# Loss = 0.3371, Accuracy = 0.8636
# Validation accuracy: 0.9247311827956989
# Training epoch 15...
# Loss = 0.4224, Accuracy = 0.8336
# Validation accuracy: 0.9086021505376344
# Training epoch 16...
# Loss = 0.3559, Accuracy = 0.8432
# Validation accuracy: 0.9301075268817204
# Training epoch 17...
# Loss = 0.373, Accuracy = 0.8324
# Validation accuracy: 0.946236559139785
# Training epoch 18...
# Loss = 0.3164, Accuracy = 0.8665
# Validation accuracy: 0.9731182795698925
# Training epoch 19...
# Loss = 0.3153, Accuracy = 0.8659
# Validation accuracy: 0.9354838709677419
# Fold 2
# Training epoch 0...
# Loss = 1.069, Accuracy = 0.4321
# Validation accuracy: 0.6989247311827957
# Training epoch 1...
# Loss = 0.867, Accuracy = 0.5972
# Validation accuracy: 0.8010752688172043
# Training epoch 2...
# Loss = 0.6911, Accuracy = 0.6822
# Validation accuracy: 0.8279569892473119
# Training epoch 3...
# Loss = 0.6027, Accuracy = 0.7415
# Validation accuracy: 0.8225806451612904
# Training epoch 4...
# Loss = 0.5484, Accuracy = 0.757
# Validation accuracy: 0.8548387096774194
# Training epoch 5...
# Loss = 0.4824, Accuracy = 0.7822
# Validation accuracy: 0.8709677419354839
# Training epoch 6...
# Loss = 0.4729, Accuracy = 0.8025
# Validation accuracy: 0.9086021505376344
# Training epoch 7...
# Loss = 0.4289, Accuracy = 0.8157
# Validation accuracy: 0.9516129032258065
# Training epoch 8...
# Loss = 0.3957, Accuracy = 0.8366
# Validation accuracy: 0.9301075268817204
# Training epoch 9...
# Loss = 0.3861, Accuracy = 0.8504
# Validation accuracy: 0.9139784946236559
# Training epoch 10...
# Loss = 0.4107, Accuracy = 0.8187
# Validation accuracy: 0.8494623655913979
# Training epoch 11...
# Loss = 0.4039, Accuracy = 0.8175
# Validation accuracy: 0.9516129032258065
# Training epoch 12...
# Loss = 0.3392, Accuracy = 0.8677
# Validation accuracy: 0.9247311827956989
# Training epoch 13...
# Loss = 0.3032, Accuracy = 0.8731
# Validation accuracy: 0.9354838709677419
# Training epoch 14...
# Loss = 0.3144, Accuracy = 0.8624
# Validation accuracy: 0.946236559139785
# Training epoch 15...
# Loss = 0.2689, Accuracy = 0.8953
# Validation accuracy: 0.9516129032258065
# Training epoch 16...
# Loss = 0.254, Accuracy = 0.8923
# Validation accuracy: 0.946236559139785
# Training epoch 17...
# Loss = 0.2574, Accuracy = 0.8887
# Validation accuracy: 0.9247311827956989
# Training epoch 18...
# Loss = 0.229, Accuracy = 0.9054
# Validation accuracy: 0.946236559139785
# Training epoch 19...
# Loss = 0.2159, Accuracy = 0.912
# Validation accuracy: 0.9623655913978495
# Fold 3
# Training epoch 0...
# Loss = 1.0138, Accuracy = 0.5111
# Validation accuracy: 0.6075268817204301
# Training epoch 1...
# Loss = 0.7427, Accuracy = 0.693
# Validation accuracy: 0.8387096774193549
# Training epoch 2...
# Loss = 0.6391, Accuracy = 0.7355
# Validation accuracy: 0.8172043010752689
# Training epoch 3...
# Loss = 0.5841, Accuracy = 0.7558
# Validation accuracy: 0.8279569892473119
# Training epoch 4...
# Loss = 0.5266, Accuracy = 0.787
# Validation accuracy: 0.8225806451612904
# Training epoch 5...
# Loss = 0.4665, Accuracy = 0.8103
# Validation accuracy: 0.8978494623655914
# Training epoch 6...
# Loss = 0.4384, Accuracy = 0.8414
# Validation accuracy: 0.8817204301075269
# Training epoch 7...
# Loss = 0.4072, Accuracy = 0.8468
# Validation accuracy: 0.8978494623655914
# Training epoch 8...
# Loss = 0.3652, Accuracy = 0.86
# Validation accuracy: 0.8924731182795699
# Training epoch 9...
# Loss = 0.3419, Accuracy = 0.8683
# Validation accuracy: 0.9086021505376344
# Training epoch 10...
# Loss = 0.3216, Accuracy = 0.8606
# Validation accuracy: 0.9301075268817204
# Training epoch 11...
# Loss = 0.3195, Accuracy = 0.8683
# Validation accuracy: 0.9086021505376344
# Training epoch 12...
# Loss = 0.2862, Accuracy = 0.8893
# Validation accuracy: 0.9086021505376344
# Training epoch 13...
# Loss = 0.25, Accuracy = 0.9072
# Validation accuracy: 0.956989247311828
# Training epoch 14...
# Loss = 0.2509, Accuracy = 0.8935
# Validation accuracy: 0.9301075268817204
# Training epoch 15...
# Loss = 0.257, Accuracy = 0.9042
# Validation accuracy: 0.9731182795698925
# Training epoch 16...
# Loss = 0.2578, Accuracy = 0.8983
# Validation accuracy: 0.9354838709677419
# Training epoch 17...
# Loss = 0.2545, Accuracy = 0.9031
# Validation accuracy: 0.9354838709677419
# Training epoch 18...
# Loss = 0.2471, Accuracy = 0.8989
# Validation accuracy: 0.956989247311828
# Training epoch 19...
# Loss = 0.189, Accuracy = 0.9246
# Validation accuracy: 0.9408602150537635
# Fold 4
# Training epoch 0...
# Loss = 1.0354, Accuracy = 0.4847
# Validation accuracy: 0.6021505376344086
# Training epoch 1...
# Loss = 0.7702, Accuracy = 0.6541
# Validation accuracy: 0.6935483870967742
# Training epoch 2...
# Loss = 0.6858, Accuracy = 0.7056
# Validation accuracy: 0.7580645161290323
# Training epoch 3...
# Loss = 0.6065, Accuracy = 0.7289
# Validation accuracy: 0.8548387096774194
# Training epoch 4...
# Loss = 0.5395, Accuracy = 0.766
# Validation accuracy: 0.8763440860215054
# Training epoch 5...
# Loss = 0.4698, Accuracy = 0.8025
# Validation accuracy: 0.8548387096774194
# Training epoch 6...
# Loss = 0.4615, Accuracy = 0.8007
# Validation accuracy: 0.7956989247311828
# Training epoch 7...
# Loss = 0.5651, Accuracy = 0.763
# Validation accuracy: 0.7795698924731183
# Training epoch 8...
# Loss = 0.517, Accuracy = 0.7893
# Validation accuracy: 0.8655913978494624
# Training epoch 9...
# Loss = 0.4709, Accuracy = 0.7953
# Validation accuracy: 0.8763440860215054
# Training epoch 10...
# Loss = 0.4339, Accuracy = 0.8091
# Validation accuracy: 0.8763440860215054
# Training epoch 11...
# Loss = 0.4322, Accuracy = 0.8181
# Validation accuracy: 0.8924731182795699
# Training epoch 12...
# Loss = 0.3509, Accuracy = 0.854
# Validation accuracy: 0.8548387096774194
# Training epoch 13...
# Loss = 0.3764, Accuracy = 0.8372
# Validation accuracy: 0.8870967741935484
# Training epoch 14...
# Loss = 0.3099, Accuracy = 0.8654
# Validation accuracy: 0.9408602150537635
# Training epoch 15...
# Loss = 0.3063, Accuracy = 0.8797
# Validation accuracy: 0.9193548387096774
# Training epoch 16...
# Loss = 0.2938, Accuracy = 0.8749
# Validation accuracy: 0.9193548387096774
# Training epoch 17...
# Loss = 0.2822, Accuracy = 0.8791
# Validation accuracy: 0.9516129032258065
# Training epoch 18...
# Loss = 0.2983, Accuracy = 0.8731
# Validation accuracy: 0.9032258064516129
# Training epoch 19...
# Loss = 0.2616, Accuracy = 0.8989
# Validation accuracy: 0.9408602150537635
# Fold 5
# Training epoch 0...
# Loss = 1.0292, Accuracy = 0.4865
# Validation accuracy: 0.7204301075268817
# Training epoch 1...
# Loss = 0.777, Accuracy = 0.6565
# Validation accuracy: 0.8387096774193549
# Training epoch 2...
# Loss = 0.6124, Accuracy = 0.7475
# Validation accuracy: 0.8655913978494624
# Training epoch 3...
# Loss = 0.5872, Accuracy = 0.7654
# Validation accuracy: 0.8602150537634409
# Training epoch 4...
# Loss = 0.5494, Accuracy = 0.7798
# Validation accuracy: 0.7956989247311828
# Training epoch 5...
# Loss = 0.4738, Accuracy = 0.8205
# Validation accuracy: 0.8978494623655914
# Training epoch 6...
# Loss = 0.48, Accuracy = 0.8294
# Validation accuracy: 0.8870967741935484
# Training epoch 7...
# Loss = 0.5269, Accuracy = 0.7971
# Validation accuracy: 0.9247311827956989
# Training epoch 8...
# Loss = 0.413, Accuracy = 0.8456
# Validation accuracy: 0.9139784946236559
# Training epoch 9...
# Loss = 0.4002, Accuracy = 0.8683
# Validation accuracy: 0.9301075268817204
# Training epoch 10...
# Loss = 0.3738, Accuracy = 0.863
# Validation accuracy: 0.9193548387096774
# Training epoch 11...
# Loss = 0.3512, Accuracy = 0.8791
# Validation accuracy: 0.9408602150537635
# Training epoch 12...
# Loss = 0.3311, Accuracy = 0.8791
# Validation accuracy: 0.956989247311828
# Training epoch 13...
# Loss = 0.2947, Accuracy = 0.8905
# Validation accuracy: 0.9247311827956989
# Training epoch 14...
# Loss = 0.3254, Accuracy = 0.8899
# Validation accuracy: 0.9408602150537635
# Training epoch 15...
# Loss = 0.298, Accuracy = 0.8911
# Validation accuracy: 0.9301075268817204
# Training epoch 16...
# Loss = 0.2845, Accuracy = 0.8923
# Validation accuracy: 0.9516129032258065
# Training epoch 17...
# Loss = 0.2633, Accuracy = 0.9042
# Validation accuracy: 0.9516129032258065
# Training epoch 18...
# Loss = 0.2646, Accuracy = 0.909
# Validation accuracy: 0.9731182795698925
# Training epoch 19...
# Loss = 0.325, Accuracy = 0.8833
# Validation accuracy: 0.967741935483871
# Fold 6
# Training epoch 0...
# Loss = 1.0908, Accuracy = 0.4279
# Validation accuracy: 0.5913978494623656
# Training epoch 1...
# Loss = 0.912, Accuracy = 0.5655
# Validation accuracy: 0.7688172043010753
# Training epoch 2...
# Loss = 0.7668, Accuracy = 0.6583
# Validation accuracy: 0.8225806451612904
# Training epoch 3...
# Loss = 0.6492, Accuracy = 0.7349
# Validation accuracy: 0.8172043010752689
# Training epoch 4...
# Loss = 0.5812, Accuracy = 0.7379
# Validation accuracy: 0.8817204301075269
# Training epoch 5...
# Loss = 0.5147, Accuracy = 0.7846
# Validation accuracy: 0.7688172043010753
# Training epoch 6...
# Loss = 0.4636, Accuracy = 0.8127
# Validation accuracy: 0.9032258064516129
# Training epoch 7...
# Loss = 0.408, Accuracy = 0.833
# Validation accuracy: 0.9247311827956989
# Training epoch 8...
# Loss = 0.3533, Accuracy = 0.8606
# Validation accuracy: 0.9139784946236559
# Training epoch 9...
# Loss = 0.3904, Accuracy = 0.8402
# Validation accuracy: 0.8870967741935484
# Training epoch 10...
# Loss = 0.3414, Accuracy = 0.863
# Validation accuracy: 0.9086021505376344
# Training epoch 11...
# Loss = 0.3342, Accuracy = 0.8689
# Validation accuracy: 0.9193548387096774
# Training epoch 12...
# Loss = 0.3598, Accuracy = 0.8636
# Validation accuracy: 0.8817204301075269
# Training epoch 13...
# Loss = 0.3141, Accuracy = 0.8821
# Validation accuracy: 0.9086021505376344
# Training epoch 14...
# Loss = 0.3099, Accuracy = 0.8827
# Validation accuracy: 0.9408602150537635
# Training epoch 15...
# Loss = 0.2882, Accuracy = 0.8857
# Validation accuracy: 0.9354838709677419
# Training epoch 16...
# Loss = 0.2448, Accuracy = 0.9007
# Validation accuracy: 0.9354838709677419
# Training epoch 17...
# Loss = 0.247, Accuracy = 0.912
# Validation accuracy: 0.9086021505376344
# Training epoch 18...
# Loss = 0.2819, Accuracy = 0.8899
# Validation accuracy: 0.9408602150537635
# Training epoch 19...
# Loss = 0.2322, Accuracy = 0.909
# Validation accuracy: 0.946236559139785
# Fold 7
# Training epoch 0...
# Loss = 1.0356, Accuracy = 0.4955
# Validation accuracy: 0.6129032258064516
# Training epoch 1...
# Loss = 0.7624, Accuracy = 0.6685
# Validation accuracy: 0.7258064516129032
# Training epoch 2...
# Loss = 0.6533, Accuracy = 0.7241
# Validation accuracy: 0.8064516129032258
# Training epoch 3...
# Loss = 0.5764, Accuracy = 0.7612
# Validation accuracy: 0.8279569892473119
# Training epoch 4...
# Loss = 0.5095, Accuracy = 0.7893
# Validation accuracy: 0.8333333333333334
# Training epoch 5...
# Loss = 0.432, Accuracy = 0.8229
# Validation accuracy: 0.8494623655913979
# Training epoch 6...
# Loss = 0.4238, Accuracy = 0.8253
# Validation accuracy: 0.8924731182795699
# Training epoch 7...
# Loss = 0.4139, Accuracy = 0.833
# Validation accuracy: 0.9193548387096774
# Training epoch 8...
# Loss = 0.3623, Accuracy = 0.848
# Validation accuracy: 0.9247311827956989
# Training epoch 9...
# Loss = 0.3359, Accuracy = 0.8695
# Validation accuracy: 0.8387096774193549
# Training epoch 10...
# Loss = 0.4215, Accuracy = 0.8312
# Validation accuracy: 0.8924731182795699
# Training epoch 11...
# Loss = 0.2976, Accuracy = 0.8749
# Validation accuracy: 0.9408602150537635
# Training epoch 12...
# Loss = 0.2705, Accuracy = 0.8941
# Validation accuracy: 0.9516129032258065
# Training epoch 13...
# Loss = 0.2787, Accuracy = 0.8917
# Validation accuracy: 0.9139784946236559
# Training epoch 14...
# Loss = 0.2465, Accuracy = 0.9108
# Validation accuracy: 0.9516129032258065
# Training epoch 15...
# Loss = 0.2193, Accuracy = 0.9222
# Validation accuracy: 0.9731182795698925
# Training epoch 16...
# Loss = 0.2258, Accuracy = 0.9162
# Validation accuracy: 0.967741935483871
# Training epoch 17...
# Loss = 0.2333, Accuracy = 0.921
# Validation accuracy: 0.9139784946236559
# Training epoch 18...
# Loss = 0.2138, Accuracy = 0.9156
# Validation accuracy: 0.9354838709677419
# Training epoch 19...
# Loss = 0.1999, Accuracy = 0.927
# Validation accuracy: 0.956989247311828
# Fold 8
# Training epoch 0...
# Loss = 1.0341, Accuracy = 0.4821
# Validation accuracy: 0.745945945945946
# Training epoch 1...
# Loss = 0.8026, Accuracy = 0.6406
# Validation accuracy: 0.7891891891891892
# Training epoch 2...
# Loss = 0.6696, Accuracy = 0.7165
# Validation accuracy: 0.7351351351351352
# Training epoch 3...
# Loss = 0.6415, Accuracy = 0.7261
# Validation accuracy: 0.8162162162162162
# Training epoch 4...
# Loss = 0.6044, Accuracy = 0.7578
# Validation accuracy: 0.8432432432432433
# Training epoch 5...
# Loss = 0.5404, Accuracy = 0.7715
# Validation accuracy: 0.8162162162162162
# Training epoch 6...
# Loss = 0.5546, Accuracy = 0.7835
# Validation accuracy: 0.8810810810810811
# Training epoch 7...
# Loss = 0.5195, Accuracy = 0.7955
# Validation accuracy: 0.827027027027027
# Training epoch 8...
# Loss = 0.4837, Accuracy = 0.8128
# Validation accuracy: 0.8702702702702703
# Training epoch 9...
# Loss = 0.4476, Accuracy = 0.8319
# Validation accuracy: 0.9081081081081082
# Training epoch 10...
# Loss = 0.4202, Accuracy = 0.8409
# Validation accuracy: 0.8648648648648649
# Training epoch 11...
# Loss = 0.4222, Accuracy = 0.8289
# Validation accuracy: 0.9081081081081082
# Training epoch 12...
# Loss = 0.3504, Accuracy = 0.863
# Validation accuracy: 0.9297297297297298
# Training epoch 13...
# Loss = 0.3788, Accuracy = 0.8439
# Validation accuracy: 0.9135135135135135
# Training epoch 14...
# Loss = 0.3349, Accuracy = 0.8535
# Validation accuracy: 0.9081081081081082
# Training epoch 15...
# Loss = 0.3566, Accuracy = 0.8421
# Validation accuracy: 0.9243243243243243
# Training epoch 16...
# Loss = 0.3499, Accuracy = 0.8618
# Validation accuracy: 0.9081081081081082
# Training epoch 17...
# Loss = 0.3433, Accuracy = 0.8648
# Validation accuracy: 0.918918918918919
# Training epoch 18...
# Loss = 0.2824, Accuracy = 0.8816
# Validation accuracy: 0.9243243243243243
# Training epoch 19...
# Loss = 0.2771, Accuracy = 0.8941
# Validation accuracy: 0.9243243243243243
# Fold 9
# Training epoch 0...
# Loss = 1.0511, Accuracy = 0.4689
# Validation accuracy: 0.6864864864864865
# Training epoch 1...
# Loss = 0.7911, Accuracy = 0.6429
# Validation accuracy: 0.8324324324324325
# Training epoch 2...
# Loss = 0.6374, Accuracy = 0.7285
# Validation accuracy: 0.8594594594594595
# Training epoch 3...
# Loss = 0.5488, Accuracy = 0.7775
# Validation accuracy: 0.8756756756756757
# Training epoch 4...
# Loss = 0.4919, Accuracy = 0.808
# Validation accuracy: 0.8756756756756757
# Training epoch 5...
# Loss = 0.447, Accuracy = 0.8158
# Validation accuracy: 0.8972972972972973
# Training epoch 6...
# Loss = 0.4245, Accuracy = 0.8391
# Validation accuracy: 0.8648648648648649
# Training epoch 7...
# Loss = 0.4048, Accuracy = 0.8373
# Validation accuracy: 0.9135135135135135
# Training epoch 8...
# Loss = 0.3284, Accuracy = 0.878
# Validation accuracy: 0.9405405405405406
# Training epoch 9...
# Loss = 0.3235, Accuracy = 0.8798
# Validation accuracy: 0.918918918918919
# Training epoch 10...
# Loss = 0.2802, Accuracy = 0.8935
# Validation accuracy: 0.9459459459459459
# Training epoch 11...
# Loss = 0.2699, Accuracy = 0.8989
# Validation accuracy: 0.9459459459459459
# Training epoch 12...
# Loss = 0.3733, Accuracy = 0.8493
# Validation accuracy: 0.9459459459459459
# Training epoch 13...
# Loss = 0.263, Accuracy = 0.8965
# Validation accuracy: 0.9351351351351351
# Training epoch 14...
# Loss = 0.2487, Accuracy = 0.9067
# Validation accuracy: 0.9459459459459459
# Training epoch 15...
# Loss = 0.2429, Accuracy = 0.8995
# Validation accuracy: 0.9567567567567568
# Training epoch 16...
# Loss = 0.2382, Accuracy = 0.9097
# Validation accuracy: 0.9297297297297298
# Training epoch 17...
# Loss = 0.2823, Accuracy = 0.884
# Validation accuracy: 0.9513513513513514
# Training epoch 18...
# Loss = 0.2351, Accuracy = 0.9103
# Validation accuracy: 0.9621621621621622
# Training epoch 19...
# Loss = 0.2332, Accuracy = 0.9121
# Validation accuracy: 0.9135135135135135
# Fold 10
# Training epoch 0...
# Loss = 1.0129, Accuracy = 0.4988
# Validation accuracy: 0.7297297297297297
# Training epoch 1...
# Loss = 0.8022, Accuracy = 0.6537
# Validation accuracy: 0.827027027027027
# Training epoch 2...
# Loss = 0.6284, Accuracy = 0.7434
# Validation accuracy: 0.8432432432432433
# Training epoch 3...
# Loss = 0.5984, Accuracy = 0.7667
# Validation accuracy: 0.8864864864864865
# Training epoch 4...
# Loss = 0.5583, Accuracy = 0.7799
# Validation accuracy: 0.8756756756756757
# Training epoch 5...
# Loss = 0.4836, Accuracy = 0.805
# Validation accuracy: 0.9135135135135135
# Training epoch 6...
# Loss = 0.4988, Accuracy = 0.8026
# Validation accuracy: 0.9351351351351351
# Training epoch 7...
# Loss = 0.4649, Accuracy = 0.814
# Validation accuracy: 0.9297297297297298
# Training epoch 8...
# Loss = 0.3945, Accuracy = 0.8403
# Validation accuracy: 0.9405405405405406
# Training epoch 9...
# Loss = 0.4162, Accuracy = 0.8313
# Validation accuracy: 0.9027027027027027
# Training epoch 10...
# Loss = 0.3779, Accuracy = 0.8445
# Validation accuracy: 0.9297297297297298
# Training epoch 11...
# Loss = 0.3923, Accuracy = 0.8433
# Validation accuracy: 0.9297297297297298
# Training epoch 12...
# Loss = 0.3476, Accuracy = 0.8481
# Validation accuracy: 0.918918918918919
# Training epoch 13...
# Loss = 0.3409, Accuracy = 0.8571
# Validation accuracy: 0.9351351351351351
# Training epoch 14...
# Loss = 0.3441, Accuracy = 0.8523
# Validation accuracy: 0.9351351351351351
# Training epoch 15...
# Loss = 0.3228, Accuracy = 0.8672
# Validation accuracy: 0.9513513513513514
# Training epoch 16...
# Loss = 0.2988, Accuracy = 0.866
# Validation accuracy: 0.9459459459459459
# Training epoch 17...
# Loss = 0.3207, Accuracy = 0.8606
# Validation accuracy: 0.9243243243243243
# Training epoch 18...
# Loss = 0.3086, Accuracy = 0.8738
# Validation accuracy: 0.918918918918919
# Training epoch 19...
# Loss = 0.3024, Accuracy = 0.8684
# Validation accuracy: 0.9459459459459459

# %%
#  Convert to DataFrame
hist_df = pd.DataFrame(history) # 200 rows, one row per epoch (with fold and epoch columns to identify them)
summ_df = pd.DataFrame(fold_summary) # 10 rows,one row per fold (e.g., best/last metrics)

# Safety: ensure numeric
for c in ["fold", "epoch"]:
    hist_df[c] = hist_df[c].astype(int)

# Per-fold curves: Loss
plt.figure(figsize=(10, 6))
for fold in sorted(hist_df["fold"].unique()):
    d = hist_df[hist_df["fold"] == fold].sort_values("epoch")
    plt.plot(d["epoch"], d["train_loss"], alpha=0.35)
    plt.plot(d["epoch"], d["val_loss"],   alpha=0.75)
plt.title("Train/Val loss per fold")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True, alpha=0.3) 
plt.show()

# Per-fold curves: Accuracy 
plt.figure(figsize=(10, 6))
for fold in sorted(hist_df["fold"].unique()):
    d = hist_df[hist_df["fold"] == fold].sort_values("epoch")
    plt.plot(d["epoch"], d["train_acc"], alpha=0.35)
    plt.plot(d["epoch"], d["val_acc"],   alpha=0.75)
plt.title("Train/Val accuracy per fold")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.ylim(0, 1)
plt.grid(True, alpha=0.3)
plt.show()

# Mean ± std across folds per epoch, agg is a df with 20 rows and 8 cols
agg = ( 
    hist_df
    .groupby("epoch")
    .agg(
        train_loss_mean=("train_loss", "mean"),
        train_loss_std =("train_loss", "std"),
        val_loss_mean  =("val_loss", "mean"),
        val_loss_std   =("val_loss", "std"),
        train_acc_mean =("train_acc", "mean"),
        train_acc_std  =("train_acc", "std"),
        val_acc_mean   =("val_acc", "mean"),
        val_acc_std    =("val_acc", "std"),
    )
    .reset_index()
)

# Loss mean ± std
plt.figure(figsize=(10, 6))
plt.plot(agg["epoch"], agg["train_loss_mean"], label="train (mean)")
plt.fill_between(
    agg["epoch"],
    agg["train_loss_mean"] - agg["train_loss_std"].fillna(0),
    agg["train_loss_mean"] + agg["train_loss_std"].fillna(0),
    alpha=0.2
)
plt.plot(agg["epoch"], agg["val_loss_mean"], label="val (mean)")
plt.fill_between(
    agg["epoch"],
    agg["val_loss_mean"] - agg["val_loss_std"].fillna(0),
    agg["val_loss_mean"] + agg["val_loss_std"].fillna(0),
    alpha=0.2
)
plt.title("Loss across folds (mean ± std)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# Accuracy mean ± std
plt.figure(figsize=(10, 6))
plt.plot(agg["epoch"], agg["train_acc_mean"], label="train (mean)")
plt.fill_between(
    agg["epoch"],
    agg["train_acc_mean"] - agg["train_acc_std"].fillna(0),
    agg["train_acc_mean"] + agg["train_acc_std"].fillna(0),
    alpha=0.2
)
plt.plot(agg["epoch"], agg["val_acc_mean"], label="val (mean)")
plt.fill_between(
    agg["epoch"],
    agg["val_acc_mean"] - agg["val_acc_std"].fillna(0),
    agg["val_acc_mean"] + agg["val_acc_std"].fillna(0),
    alpha=0.2
)
plt.title("Accuracy across folds (mean ± std)")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.ylim(0, 1)
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# Fold-level summary plots 
# Best val acc per fold
plt.figure(figsize=(10, 4))
plt.bar(summ_df["fold"], summ_df["best_val_acc"])
plt.title("Best validation accuracy per fold")
plt.xlabel("Fold")
plt.ylabel("Best val acc")
plt.ylim(0, 1)
plt.grid(True, axis="y", alpha=0.3)
plt.show()

# Best val loss per fold
plt.figure(figsize=(10, 4))
plt.bar(summ_df["fold"], summ_df["best_val_loss"])
plt.title("Best validation loss per fold")
plt.xlabel("Fold")
plt.ylabel("Best val loss")
plt.grid(True, axis="y", alpha=0.3)
plt.show()

# Print a numeric summary
print("Best val acc: mean =", summ_df["best_val_acc"].mean(), "std =", summ_df["best_val_acc"].std())
print("Best val loss: mean =", summ_df["best_val_loss"].mean(), "std =", summ_df["best_val_loss"].std())
# Out:
# Best val acc: mean = 0.9595931415286255 std = 0.014711434507856306
# Best val loss: mean = 0.12939145122620904 std = 0.0352495751410178

# %% [markdown]
# Cross‑validation (CV) mainly gives you a more reliable estimate of generalization (how performance changes across different train/validation splits) and a safer way to pick things like architecture, regularization, and early‑stopping epoch without getting lucky on one particular split. Scikit‑learn even warns that training and testing on the same data is a methodological mistake and presents CV as a way to evaluate performance on unseen folds.

# %%
final_cnn = MediumCNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(final_cnn.parameters(), lr=0.0005115859153484923, momentum=0.9)

final_loader = torch.utils.data.DataLoader(full_ds, batch_size=16, shuffle=True, num_workers=2)

EPOCHS_FINAL = 20  # or pick based on CV curves

for epoch in range(EPOCHS_FINAL):
    final_cnn.train()
    for inputs, labels in final_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = final_cnn(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

torch.save(final_cnn.state_dict(), "trained_cnn_final.pth") # saves weights and biases

# %%
TEST_DIR = "/Users/alessandro/Progetti/RockPaperScissorNew/rps-split/test"  


device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")


img_size = (256, 256)
test_transform = transforms.Compose([
    transforms.Resize(img_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
])

# Load test set
test_ds = datasets.ImageFolder(TEST_DIR, transform=test_transform) 
print("Test classes:", test_ds.classes, "  n_test:", len(test_ds))


cnn = MediumCNN().to(device)
cnn.load_state_dict(torch.load("trained_cnn.pth", map_location=device))
cnn.eval()


# Dataloader 
test_loader = torch.utils.data.DataLoader(
    test_ds,
    batch_size=16,
    shuffle=False,
    num_workers=2,
)

# Evaluate
criterion = nn.CrossEntropyLoss()
total, correct, test_loss_sum = 0, 0, 0.0

all_preds = []
all_labels = []

with torch.no_grad():
    for x, y in test_loader:
        x, y = x.to(device), y.to(device)
        logits = cnn(x)
        loss = criterion(logits, y)

        bs = y.size(0)
        test_loss_sum += loss.item() * bs
        preds = logits.argmax(dim=1)

        correct += (preds == y).sum().item()
        total += bs

        all_preds.append(preds.cpu()) # tensors on GPU cannot be directly converted to numpy
        all_labels.append(y.cpu())

test_loss = test_loss_sum / max(total, 1)
test_acc = correct / max(total, 1)


print(f"Test loss: {test_loss:.4f}")
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Test classes: ['paper', 'rock', 'scissors']   n_test: 331
# Test loss: 0.1294
# Test accuracy: 0.9668

# %%
# Concatenate the tensors you collected during evaluation
y_true = torch.cat(all_labels).numpy()
y_pred = torch.cat(all_preds).numpy()

# Confusion matrix (counts)
cm = confusion_matrix(y_true, y_pred)  # C[i, j] = # true=i predicted=j 
print("Confusion matrix (counts):\n", cm)

# Normalized by true class (rows sum to 1)
cm_norm = confusion_matrix(y_true, y_pred, normalize="true")  # normalize='true' -> row-normalized 

# Plot (counts)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=test_ds.classes)
disp.plot(xticks_rotation=45)
plt.title("Confusion matrix (counts)")
plt.tight_layout()
plt.show()  # ConfusionMatrixDisplay is intended for plotting a confusion matrix 

# Plot (row-normalized)
disp_norm = ConfusionMatrixDisplay(confusion_matrix=cm_norm, display_labels=test_ds.classes)
disp_norm.plot(xticks_rotation=45, values_format=".2f")
plt.title("Confusion matrix (normalized by true class)")
plt.tight_layout()
plt.show()  # normalize option controls how entries are normalized 

# Classification report (precision/recall/F1 per class)
print("\nClassification report:")
print(classification_report(y_true, y_pred, target_names=test_ds.classes, digits=4))  # target_names labels classes
# Out:
# Confusion matrix (counts):
#  [[100   1   7]
#  [  0 109   1]
#  [  0   2 111]]
# Classification report:
#               precision    recall  f1-score   support
#
#        paper     1.0000    0.9259    0.9615       108
#         rock     0.9732    0.9909    0.9820       110
#     scissors     0.9328    0.9823    0.9569       113
#
#     accuracy                         0.9668       331
#    macro avg     0.9687    0.9664    0.9668       331
# weighted avg     0.9681    0.9668    0.9667       331
