# %% [markdown]
# ### 1 - Simplest CNN architecture
#
# In this simple architecture, we create a simple convolutional neural network with a convolutional layer and a pool layer.
# For the convolutional layer we want to tune the hyper parameters of out_channels and kernel_size.
# To fine-tune hyperparameters we will use Ray, an open source unified framowork developed by PyTorch Fundation.
# Ray Tune offers a variety of search space distributions to suit different parameter tupes: loguniform, uniform, choice, randint, grid and more.

# %%
import torch 
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import random
from ray import tune 
import torch.optim as optim # for PyTorch optimizers
from ray import tune # to report metrics back to Ray Tune for logging the best trial
from ray.tune import Checkpoint # Ray Train checkpoint object
import tempfile
import os
import math
import ray
from ray.tune.schedulers import ASHAScheduler # early stopping strategy that stops poorly performing trials
import pandas as pd
import matplotlib.pyplot as plt
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
# Out:
# /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
def set_seed(seed=42):
    """
    Set random seeds for reproducibility across all libraries.
    
    Args:
        seed: Integer seed value (42 is traditional, but any int works)
    """
    # Python's built-in random module
    random.seed(seed)
    
    # NumPy
    np.random.seed(seed)
    
    # PyTorch
    torch.manual_seed(seed)
    
    # PyTorch MPS 
    if torch.backends.mps.is_available():
        torch.mps.manual_seed(seed)
    
    # Make PyTorch deterministic (slower but reproducible)
    torch.backends.cudnn.deterministic = True 
    torch.backends.cudnn.benchmark = False 
    
    # Set environment variable for Python hash seed
    os.environ['PYTHONHASHSEED'] = str(seed)


set_seed(42)

# %%
class SimpleCNN(nn.Module):
    def __init__(self, num_classes = 3 , out_channels = 8, conv_kernel_size = 3 , pool_kernel_size = 2):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels = 3, out_channels = out_channels, kernel_size = conv_kernel_size, padding = conv_kernel_size // 2 ) # for stride = 1, padding = conv_kernel_size // 2 seems to be the rule of thumb
        self.pool = nn.MaxPool2d(kernel_size = pool_kernel_size)
        self.fc_layer = nn.LazyLinear(num_classes) #PyTorch infers in_feature the first time it sees data, so it always matches the flatten output

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.pool(x)
        x = torch.flatten(x, 1) # flatten all dimensions except batch dimension
        x = self.fc_layer(x)
        return x

# %% [markdown]
# Now via the config dictionary, we will define our search space

# %% [markdown]
# - tune.choice() picks one value from a finite list, all with equal probability: it is like a discrete frid over those options
# - tune.loguniform(low, high): samples a continuous value between low and high, but uniformly in log space.
# - tune.choice() is a random search over a finite set while grid search is "try every combo in the set".
#
# In the following code we grid search over out_channels and conv_kernel_size to study capacity vs kernel size.
#
# Grid search fixes the architecture hyperparameters and enumerates all combinations. For each architecture, we still do a small random search over optimization hyperparameters (lr, batch_size, etc.), controlled by num_samples. We chose num_samples = 10 (or 5) to balance thoroughness and compute time.

# %%
# config will contain specifications on how to generate values, not the actual values.  

config = {
        # Model Architecture
        "out_channels" : tune.grid_search([8,16,32]), # picked a small range that gradually increases capacity while keeping computation manageable
        "conv_kernel_size" : tune.grid_search([3,4,7]), # Small to moderately large kernels to see how much spatial context the model needs for our images
        "pool_kernel_size" : tune.choice([2, 4]), # 2 is a standard downsampling (keeps more spatial detail). 4 is more aggressive, more information loss but faster
        
        # Training Hyperparameteres:
        "lr" : tune.loguniform(0.0001, 0.1), 
        "batch_size" : tune.choice([16, 32, 64]) # Common batch sizes to balance memory and convergence speed

}

# %% [markdown]
# Datasets:

# %% [markdown]
# Training function.
# Ray Tune requires a training function that accepts a configuration dictionary and runs the main training loop.
# As Ray Tune runs diffrent trials, it updates the configuration dictionary for each trial.

# %% [markdown]
# SDG = Stochastic Gradient Descent: an optimization algorithm that updates your model's parameters by moving them a small step in the direction that reduces the loss, using a noisy estimate of the gradient computed from a mini-batch (rather than the full dataset)

# %%
# later on Ray Tune will call this function 10 times with different hyperparameter combinations from the config, and each time it will train a model and report back the validation loss and accuracy for that trial. Ray Tune will keep track of all the trials and their metrics, and at the end we can analyze which hyperparameter combination performed best.

def train1(config, data_dir = None):
    """ Create a model instance """
    # Load datasets locally in the training function
    from torchvision import transforms, datasets # imports torchvision utilities locally inside the function - common in RayTune examples so each worker/trial can import what it needs

    img_size = (256, 256)
    train_transform = transforms.Compose([
        transforms.Resize(img_size),
        transforms.RandomHorizontalFlip(p = 0.5),
        transforms.RandomRotation(degrees= 15),
        transforms.ColorJitter(
            brightness = 0.2,
            saturation = 0.2,
            contrast = 0.2,
            hue = 0.1,
        ),
        transforms.ToTensor(),
        transforms.Normalize(mean = [0.5, 0.5, 0.5],std = [0.5,0.5,0.5])
    ])


    val_transform = transforms.Compose([
        transforms.Resize(img_size),
        transforms.ToTensor(),
        transforms.Normalize(mean = [0.5, 0.5, 0.5],std = [0.5,0.5,0.5])
    ])


    train_ds_local = datasets.ImageFolder("/Users/alessandro/Progetti/RockPaperScissorNew/rps-split/train", transform=train_transform)
    val_ds_local = datasets.ImageFolder("/Users/alessandro/Progetti/RockPaperScissorNew/rps-split/val", transform=val_transform)

    cnn = SimpleCNN(
        out_channels= config["out_channels"],
        conv_kernel_size = config["conv_kernel_size"] ,
        pool_kernel_size = config["pool_kernel_size"] )


    device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
    cnn = cnn.to(device) # moves model parameters (weights and biases) to the target device


    criterion = nn.CrossEntropyLoss() #lossCriterion
    optimizer = optim.SGD(cnn.parameters(), lr = config["lr"], momentum = 0.9) 

    trainloader = torch.utils.data.DataLoader(
        train_ds_local,
        batch_size = int(config["batch_size"]),
        shuffle = True,
        num_workers = 2,
    )
    valloader = torch.utils.data.DataLoader(
        val_ds_local,
        batch_size = int(config["batch_size"]),
        shuffle = False,
        num_workers = 2,
    )

    best_val_loss = math.inf

    for epoch in range(10):
        cnn.train() # enables training mode (dropout, batchnorm)
        running_loss = 0.0
        n_train = 0

        for inputs, labels in trainloader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad() # zeroes out the gradients from the previous step
            outputs = cnn(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * labels.size(0) # accumulate total loss for the epoch (loss.item() gives average loss per sample in the batch, multiplying by batch size gives total loss for that batch)
            n_train += labels.size(0)

        train_loss = running_loss / max(n_train, 1)

        cnn.eval()
        val_loss = 0.0
        total = 0
        correct = 0

        with torch.no_grad(): # disables gradient calculation, which reduces memory usage and speeds up computations during evaluation since we don't need gradients for backpropagation
            for inputs, labels in valloader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = cnn(inputs) # raw output logits from the model
                loss = criterion(outputs, labels)

                val_loss += loss.item() * labels.size(0)
                preds = outputs.argmax(dim=1) 
                correct += (preds == labels).sum().item()
                total += labels.size(0)

        val_loss = val_loss / max(total, 1)
        val_acc = correct / max(total, 1)

        # Report metrics to Ray Tune
        report_dict = {"loss": float(val_loss), "accuracy": float(val_acc), "train_loss": float(train_loss)} # Ray Tune can't handle tensors correctly so we convert to floats before reporting

        if val_loss < best_val_loss: # best model saving to then have the model (from the best trial), not necessarily the latest one
            best_val_loss = val_loss
            with tempfile.TemporaryDirectory() as checkpointdir: # creates a temporary directory that will be automatically cleaned up after the block. We use this to save our model checkpoint for the best trial.
                ckptpath = os.path.join(checkpointdir, "model.pt")
                torch.save({                                     
                    "model_state": cnn.state_dict(),            # all the model's learned weights and biases
                    "optimizer_state": optimizer.state_dict(),  # otimizer's internal state (momentum values, learning rate,...)
                    "epoch": epoch,
                    "best_val_loss": best_val_loss}, ckptpath)
                checkpoint = Checkpoint.from_directory(checkpointdir) # Ray copies the checkpoint directory to its own storage and creates a Checkpoint object that points to it
                # pass metrics as kwargs and attach checkpoint
                tune.report(report_dict, checkpoint=checkpoint) # sends all the metrics to Ray Tune, along with the checkpoint for this trial
        else:
            tune.report(report_dict) # even if this trial isn't the best, we still report its metrics to Ray Tune for logging and analysis 
                                    # and for Ray Tune to know when to stop trials early with ASHA scheduler based on the reported metrics.

# %%
# Shutdown existing Ray instance if any - this prevents conflicts. 
if ray.is_initialized():
    ray.shutdown()


# Start Ray with reduced resource allocation
ray.init(ignore_reinit_error=True, include_dashboard=False, num_cpus=6)


scheduler = ASHAScheduler( #Async Successive Halving Algorithm 
    max_t=10,          # matches max_epochs in train1 - even the best trial will stop after 10 epochs 
    grace_period=1,    # minimum number of epochs a trial runs before considered for early stopping
    reduction_factor=2 # ASHAScheduler stops half of the trials at each decision point 
)


# defines settings that apply to the whole tuning run (not a single model) - regards checkpoint management and storage
run_config = tune.RunConfig(
    checkpoint_config=tune.CheckpointConfig( # we are telling Ray  how to manage checkpoints produced by the training function
        num_to_keep=1,
        checkpoint_score_attribute="loss",
        checkpoint_score_order="min",
    )
)



cpus_per_trial = 2 

# this is the ray tune instance that will run the hyperparameter search, it takes the training function, tune configuration (which includes the 
# scheduler and number of samples), run configuration (which includes checkpoint management settings), and the hyperparameter search space defined in config
tuner = tune.Tuner(
    tune.with_resources(train1, resources={"cpu": cpus_per_trial}),
    tune_config=tune.TuneConfig(
        metric="loss",
        mode="min",
        scheduler=scheduler,
        num_samples=10,   # number of trials, how many different random hyperparameter combinations to try
    ),
    run_config=run_config, # attach the run level configuration
    param_space=config,    # the search space dict 
)


result_grid = tuner.fit() # starts the hyperparameter tuning


best_result = result_grid.get_best_result(metric="loss", mode="min") # selects the best trial according to minimum loss from the completed results
best_config = best_result.config # extracts the hyperparameter configuration used by the best trial
best_ckpt = best_result.checkpoint
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2026-02-11 12:13:47</td></tr>
# <tr><td>Running for: </td><td>01:07:38.98        </td></tr>
# <tr><td>Memory:      </td><td>8.9/16.0 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=90<br>Bracket: Iter 8.000: -0.5034752264161783 | Iter 4.000: -0.593872422638115 | Iter 2.000: -0.734252474333611 | Iter 1.000: -0.9443681960456942<br>Logical resource usage: 2.0/6 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name        </th><th>status    </th><th>loc           </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  conv_kernel_size</th><th style="text-align: right;">         lr</th><th style="text-align: right;">  out_channels</th><th style="text-align: right;">  pool_kernel_size</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">            loss</th><th style="text-align: right;">  accuracy</th><th style="text-align: right;">      train_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>train1_4906e_00000</td><td>TERMINATED</td><td>127.0.0.1:4202</td><td style="text-align: right;">          64</td><td style="text-align: right;">                 3</td><td style="text-align: right;">0.0245261  </td><td style="text-align: right;">             8</td><td style="text-align: right;">                 2</td><td style="text-align: right;">     8</td><td style="text-align: right;">        233.131 </td><td style="text-align: right;">     1.10201    </td><td style="text-align: right;">  0.319018</td><td style="text-align: right;">     1.11066    </td></tr>
# <tr><td>train1_4906e_00001</td><td>TERMINATED</td><td>127.0.0.1:4204</td><td style="text-align: right;">          16</td><td style="text-align: right;">                 4</td><td style="text-align: right;">0.021831   </td><td style="text-align: right;">             8</td><td style="text-align: right;">                 2</td><td style="text-align: right;">     1</td><td style="text-align: right;">         33.0478</td><td style="text-align: right;">     1.09849    </td><td style="text-align: right;">  0.331288</td><td style="text-align: right;">    31.8215     </td></tr>
# <tr><td>train1_4906e_00002</td><td>TERMINATED</td><td>127.0.0.1:4203</td><td style="text-align: right;">          64</td><td style="text-align: right;">                 7</td><td style="text-align: right;">0.0021752  </td><td style="text-align: right;">             8</td><td style="text-align: right;">                 2</td><td style="text-align: right;">    10</td><td style="text-align: right;">        289.459 </td><td style="text-align: right;">     0.634534   </td><td style="text-align: right;">  0.800613</td><td style="text-align: right;">     0.698129   </td></tr>
# <tr><td>train1_4906e_00003</td><td>TERMINATED</td><td>127.0.0.1:4268</td><td style="text-align: right;">          16</td><td style="text-align: right;">                 3</td><td style="text-align: right;">0.00238642 </td><td style="text-align: right;">            16</td><td style="text-align: right;">                 2</td><td style="text-align: right;">    10</td><td style="text-align: right;">        283.011 </td><td style="text-align: right;">     0.871037   </td><td style="text-align: right;">  0.595092</td><td style="text-align: right;">     0.857101   </td></tr>
# <tr><td>train1_4906e_00004</td><td>TERMINATED</td><td>127.0.0.1:4471</td><td style="text-align: right;">          64</td><td style="text-align: right;">                 4</td><td style="text-align: right;">0.000268288</td><td style="text-align: right;">            16</td><td style="text-align: right;">                 4</td><td style="text-align: right;">    10</td><td style="text-align: right;">        286.118 </td><td style="text-align: right;">     0.581326   </td><td style="text-align: right;">  0.803681</td><td style="text-align: right;">     0.636324   </td></tr>
# <tr><td>train1_4906e_00005</td><td>TERMINATED</td><td>127.0.0.1:4542</td><td style="text-align: right;">          32</td><td style="text-align: right;">                 7</td><td style="text-align: right;">0.00014765 </td><td style="text-align: right;">            16</td><td style="text-align: right;">                 4</td><td style="text-align: right;">    10</td><td style="text-align: right;">        293.553 </td><td style="text-align: right;">     0.570661   </td><td style="text-align: right;">  0.806748</td><td style="text-align: right;">     0.638339   </td></tr>
# <tr><td>train1_4906e_00006</td><td>TERMINATED</td><td>127.0.0.1:4571</td><td style="text-align: right;">          16</td><td style="text-align: right;">                 3</td><td style="text-align: right;">0.000100539</td><td style="text-align: right;">            32</td><td style="text-align: right;">                 4</td><td style="text-align: right;">    10</td><td style="text-align: right;">        303.368 </td><td style="text-align: right;">     0.523206   </td><td style="text-align: right;">  0.812883</td><td style="text-align: right;">     0.547137   </td></tr>
# <tr><td>train1_4906e_00007</td><td>TERMINATED</td><td>127.0.0.1:4817</td><td style="text-align: right;">          32</td><td style="text-align: right;">                 4</td><td style="text-align: right;">0.00081795 </td><td style="text-align: right;">            32</td><td style="text-align: right;">                 2</td><td style="text-align: right;">    10</td><td style="text-align: right;">        300.103 </td><td style="text-align: right;">     0.471675   </td><td style="text-align: right;">  0.849693</td><td style="text-align: right;">     0.485554   </td></tr>
# <tr><td>train1_4906e_00008</td><td>TERMINATED</td><td>127.0.0.1:4871</td><td style="text-align: right;">          16</td><td style="text-align: right;">                 7</td><td style="text-align: right;">0.00197622 </td><td style="text-align: right;">            32</td><td style="text-align: right;">                 2</td><td style="text-align: right;">     1</td><td style="text-align: right;">         37.9769</td><td style="text-align: right;">     0.983516   </td><td style="text-align: right;">  0.576687</td><td style="text-align: right;">     1.53523    </td></tr>
# <tr><td>train1_4906e_00009</td><td>TERMINATED</td><td>127.0.0.1:4913</td><td style="text-align: right;">          64</td><td style="text-align: right;">                 3</td><td style="text-align: right;">0.000137832</td><td style="text-align: right;">             8</td><td style="text-align: right;">                 2</td><td style="text-align: right;">     1</td><td style="text-align: right;">         28.5979</td><td style="text-align: right;">     1.02441    </td><td style="text-align: right;">  0.530675</td><td style="text-align: right;">     1.05949    </td></tr>
# <tr><td>train1_4906e_00010</td><td>TERMINATED</td><td>127.0.0.1:4914</td><td style="text-align: right;">          64</td><td style="text-align: right;">                 4</td><td style="text-align: right;">0.000324767</td><td style="text-align: right;">             8</td><td style="text-align: right;">                 2</td><td style="text-align: right;">    10</td><td style="text-align: right;">        282.13  </td><td style="text-align: right;">     0.562736   </td><td style="text-align: right;">  0.819018</td><td style="text-align: right;">     0.593638   </td></tr>
# <tr><td>train1_4906e_00011</td><td>TERMINATED</td><td>127.0.0.1:4949</td><td style="text-align: right;">          32</td><td style="text-align: right;">                 7</td><td style="text-align: right;">0.0702517  </td><td st
# (raylet) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (raylet)   warnings.warn(
# (train1 pid=4202) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 9x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (train1 pid=4202)   warnings.warn( [repeated 9x across cluster]
# (train1 pid=4202) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 4x across cluster]
# (train1 pid=4202)   warnings.warn( [repeated 4x across cluster]
# (pid=gcs_server) [2026-02-11 11:06:34,732 E 4189 110606] (gcs_server) gcs_server.cc:302: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2026-02-11 11:06:36,451 E 4193 110724] (raylet) main.cc:975: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (train1 pid=4204) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 4x across cluster]
# (train1 pid=4204)   warnings.warn( [repeated 4x across cluster]
# [2026-02-11 11:06:38,553 E 4176 110831] core_worker_process.cc:825: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (train1 pid=4202) [2026-02-11 11:06:40,982 E 4202 111427] core_worker_process.cc:825: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (train1 pid=4202) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00000_0_batch_size=64,conv_kernel_size=3,lr=0.0245,out_channels=8,pool_kernel_size=2_2026-02-11_11-06-08/checkpoint_000000)
# 2026-02-11 11:06:44,179	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (train1 pid=4202) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (train1 pid=4202)   warnings.warn(
# 2026-02-11 11:06:45,435	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (train1 pid=4204) [2026-02-11 11:06:40,987 E 4204 111426] core_worker_process.cc:825: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14 [repeated 2x across cluster]
# (train1 pid=4204) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00001_1_batch_size=16,conv_kernel_size=4,lr=0.0218,out_channels=8,pool_kernel_size=2_2026-02-11_11-06-08/checkpoint_000000) [repeated 2x across cluster]
# (train1 pid=4268) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 7x across cluster]
# (train1 pid=4268)   warnings.warn( [repeated 7x across cluster]
# (train1 pid=4202) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 3x across cluster]
# (train1 pid=4202)   warnings.warn( [repeated 3x across cluster]
# (train1 pid=4268) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 4x across cluster]
# (train1 pid=4268)   warnings.warn( [repeated 4x across cluster]
# (train1 pid=4202) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (train1 pid=4202)   warnings.warn(
# (train1 pid=4203) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (train1 pid=4203)   warnings.warn(
# 2026-02-11 11:07:19,241	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (train1 pid=4268) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00003_3_batch_size=16,conv_kernel_size=3,lr=0.0024,out_channels=16,pool_kernel_size=2_2026-02-11_11-06-08/checkpoint_000000)
# (train1 pid=4203) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 2x across cluster]
# (train1 pid=4203)   warnings.warn( [repeated 2x across cluster]
# (train1 pid=4268) [2026-02-11 11:07:19,468 E 4268 112522] core_worker_process.cc:825: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (train1 pid=4202) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 4x across cluster]
# (train1 pid=4202)   warnings.warn( [repeated 4x across cluster]
# (train1 pid=4202) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00000_0_batch_size=64,conv_kernel_size=3,lr=0.0245,out_channels=8,pool_kernel_size=2_2026-02-11_11-06-08/checkpoint_000001)
# (train1 pid=4268) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 4x across cluster]
# (train1 pid=4268)   warnings.warn( [repeated 4x across cluster]
# 2026-02-11 11:07:42,250	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# 2026-02-11 11:07:46,786	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (train1 pid=4268) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00003_3_batch_size=16,conv_kernel_size=3,lr=0.0024,out_channels=16,pool_kernel_size=2_2026-02-11_11-06-08/checkpoint_000001)
# (train1 pid=4268) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 6x across cluster]
# (train1 pid=4268)   warnings.warn( [repeated 6x across cluster]
# (train1 pid=4202) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 2x across cluster]
# (train1 pid=4202)   warnings.warn( [repeated 2x across cluster]
# 2026-02-11 11:08:10,618	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (train1 pid=4203) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00002_2_batch_size=64,conv_kernel_size=7,lr=0.0022,out_channels=8,pool_kernel_size=2_2026-02-11_11-06-08/checkpoint_000001)
# (train1 pid=4268) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 4x across cluster]
# (train1 pid=4268)   warnings.warn( [repeated 4x across cluster]
# 2026-02-11 11:08:14,587	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (train1 pid=4268) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00003_3_batch_size=16,conv_kernel_size=3,lr=0.0024,out_channels=16,pool_kernel_size=2_2026-02-11_11-06-08/checkpoint_000002)
# (train1 pid=4268) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 6x across cluster]
# (train1 pid=4268)   warnings.warn( [repeated 6x across cluster]
# (train1 pid=4202) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 2x across cluster]
# (train1 pid=4202)   warnings.warn( [repeated 2x across cluster]
# 2026-02-11 11:08:38,997	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (train1 pid=4203) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00002_2_batch_size=64,conv_kernel_size=7,lr=0.0022,out_channels=8,pool_kernel_size=2_2026-02-11_11-06-08/checkpoint_000002)
# (train1 pid=4268) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 4x across cluster]
# (train1 pid=4268)   warnings.warn( [repeated 4x across cluster]
# 2026-02-11 11:08:42,701	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (train1 pid=4268) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00003_3_batch_size=16,conv_kernel_size=3,lr=0.0024,out_channels=16,pool_kernel_size=2_2026-02-11_11-06-08/checkpoint_000003)
# (train1 pid=4268) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 6x across cluster]
# (train1 pid=4268)   warnings.warn( [repeated 6x across cluster]
# (train1 pid=4202) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 2x across cluster]
# (train1 pid=4202)   warnings.warn( [repeated 2x across cluster]
# (train1 pid=4202) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 5x across cluster]
# (train1 pid=4202)   warnings.warn( [repeated 5x across cluster]
# (train1 pid=4202) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 7x across cluster]
# (train1 pid=4202)   warnings.warn( [repeated 7x across cluster]
# (train1 pid=4202) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 5x across cluster]
# (train1 pid=4202)   warnings.warn( [repeated 5x across cluster]
# (train1 pid=4202) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 7x across cluster]
# (train1 pid=4202)   warnings.warn( [repeated 7x across cluster]
# (train1 pid=4203) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 5x across cluster]
# (train1 pid=4203)   warnings.warn( [repeated 5x across cluster]
# (train1 pid=4471) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 7x across cluster]
# (train1 pid=4471)   warnings.warn( [repeated 7x across cluster]
# (train1 pid=4203) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 3x across cluster]
# (train1 pid=4203)   warnings.warn( [repeated 3x across cluster]
# (train1 pid=4471) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 4x across cluster]
# (train1 pid=4471)   warnings.warn( [repeated 4x across cluster]
# 2026-02-11 11:10:34,005	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (train1 pid=4203) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00002_2_batch_size=64,conv_kernel_size=7,lr=0.0022,out_channels=8,pool_kernel_size=2_2026-02-11_11-06-08/checkpoint_000003)
# (train1 pid=4203) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (train1 pid=4203)   warnings.warn(
# (train1 pid=4203) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (train1 pid=4203)   warnings.warn(
# (train1 pid=4471) [2026-02-11 11:10:38,921 E 4471 116076] core_worker_process.cc:825: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (train1 pid=4471) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00004_4_batch_size=64,conv_kernel_size=4,lr=0.0003,out_channels=16,pool_kernel_size=4_2026-02-11_11-06-08/checkpoint_000000)
# (train1 pid=4268) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 2x across cluster]
# (train1 pid=4268)   warnings.warn( [repeated 2x across cluster]
# (train1 pid=4203) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 4x across cluster]
# (train1 pid=4203)   warnings.warn( [repeated 4x across cluster]
# (train1 pid=4471) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 4x across cluster]
# (train1 pid=4471)   warnings.warn( [repeated 4x across cluster]
# (raylet) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (raylet)   warnings.warn(
# (raylet) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (raylet)   warnings.warn(
# (train1 pid=4268) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00003_3_batch_size=16,conv_kernel_size=3,lr=0.0024,out_channels=16,pool_kernel_size=2_2026-02-11_11-06-08/checkpoint_000004)
# 2026-02-11 11:11:08,101	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (train1 pid=4471) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 7x across cluster]
# (train1 pid=4471)   warnings.warn( [repeated 7x across cluster]
# (train1 pid=4471) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00004_4_batch_size=64,conv_kernel_size=4,lr=0.0003,out_channels=16,pool_kernel_size=4_2026-02-11_11-06-08/checkpoint_000001)
# (train1 pid=4268) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 2x across cluster]
# (train1 pid=4268)   warnings.warn( [repeated 2x across cluster]
# (raylet) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 5x across cluster]
# (raylet)   warnings.warn( [repeated 5x across cluster]
# (train1 pid=4542) [2026-02-11 11:11:35,895 E 4542 117195] core_worker_process.cc:825: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (train1 pid=4471) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00004_4_batch_size=64,conv_kernel_size=4,lr=0.0003,out_channels=16,pool_kernel_size=4_2026-02-11_11-06-08/checkpoint_000002)
# 2026-02-11 11:11:38,194	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (train1 pid=4571) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 8x across cluster]
# (train1 pid=4571)   warnings.warn( [repeated 8x across cluster]
# (train1 pid=4542) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00005_5_batch_size=32,conv_kernel_size=7,lr=0.0001,out_channels=16,pool_kernel_size=4_2026-02-11_11-06-08/checkpoint_000000)
# (train1 pid=4471) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 2x across cluster]
# (train1 pid=4471)   warnings.warn( [repeated 2x across cluster]
# (train1 pid=4471) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00004_4_batch_size=64,conv_kernel_size=4,lr=0.0003,out_channels=16,pool_kernel_size=4_2026-02-11_11-06-08/checkpoint_000003)
# (train1 pid=4571) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 4x across cluster]
# (train1 pid=4571)   warnings.warn( [repeated 4x across cluster]
# (train1 pid=4571) [2026-02-11 11:12:07,719 E 4571 117695] core_worker_process.cc:825: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# 2026-02-11 11:12:09,215	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# 2026-02-11 11:12:10,777	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (train1 pid=4571) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00006_6_batch_size=16,conv_kernel_size=3,lr=0.0001,out_channels=32,pool_kernel_size=4_2026-02-11_11-06-08/checkpoint_000000) [repeated 2x across cluster]
# (train1 pid=4471) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 8x across cluster]
# (train1 pid=4471)   warnings.warn( [repeated 8x across cluster]
# (train1 pid=4471) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00004_4_batch_size=64,conv_kernel_size=4,lr=0.0003,out_channels=16,pool_kernel_size=4_2026-02-11_11-06-08/checkpoint_000004)
# (train1 pid=4571) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 4x across cluster]
# (train1 pid=4571)   warnings.warn( [repeated 4x across cluster]
# 2026-02-11 11:12:39,043	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (train1 pid=4542) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00005_5_batch_size=32,conv_kernel_size=7,lr=0.0001,out_channels=16,pool_kernel_size=4_2026-02-11_11-06-08/checkpoint_000002)
# 2026-02-11 11:12:41,155	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (train1 pid=4542) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 4x across cluster]
# (train1 pid=4542)   warnings.warn( [repeated 4x across cluster]
# (train1 pid=4571) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00006_6_batch_size=16,conv_kernel_size=3,lr=0.0001,out_channels=32,pool_kernel_size=4_2026-02-11_11-06-08/checkpoint_000001)
# (train1 pid=4471) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 4x across cluster]
# (train1 pid=4471)   warnings.warn( [repeated 4x across cluster]
# (train1 pid=4571) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 4x across cluster]
# (train1 pid=4571)   warnings.warn( [repeated 4x across cluster]
# 2026-02-11 11:13:03,689	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (train1 pid=4471) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00004_4_batch_size=64,conv_kernel_size=4,lr=0.0003,out_channels=16,pool_kernel_size=4_2026-02-11_11-06-08/checkpoint_000005)
# (train1 pid=4471) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (train1 pid=4471)   warnings.warn(
# (train1 pid=4471) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (train1 pid=4471)   warnings.warn(
# 2026-02-11 11:13:08,076	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (train1 pid=4542) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00005_5_batch_size=32,conv_kernel_size=7,lr=0.0001,out_channels=16,pool_kernel_size=4_2026-02-11_11-06-08/checkpoint_000003)
# (train1 pid=4542) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 2x across cluster]
# (train1 pid=4542)   warnings.warn( [repeated 2x across cluster]
# ...
# (train1 pid=7686) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 2x across cluster]
# (train1 pid=7686)   warnings.warn( [repeated 2x across cluster]
# (train1 pid=7958) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 4x across cluster]
# (train1 pid=7958)   warnings.warn( [repeated 4x across cluster]
# (raylet) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 3x across cluster]
# (raylet)   warnings.warn( [repeated 3x across cluster]
# (train1 pid=7969) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 4x across cluster]
# (train1 pid=7969)   warnings.warn( [repeated 4x across cluster]
# (train1 pid=7958) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00085_85_batch_size=32,conv_kernel_size=4,lr=0.0008,out_channels=16,pool_kernel_size=2_2026-02-11_11-06-08/checkpoint_000001)
# (train1 pid=8010) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 4x across cluster]
# (train1 pid=8010)   warnings.warn( [repeated 4x across cluster]
# 2026-02-11 12:11:04,598	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (train1 pid=7969) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00086_86_batch_size=16,conv_kernel_size=7,lr=0.0006,out_channels=16,pool_kernel_size=2_2026-02-11_11-06-08/checkpoint_000001)
# (train1 pid=7958) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 4x across cluster]
# (train1 pid=7958)   warnings.warn( [repeated 4x across cluster]
# (train1 pid=8010) [2026-02-11 12:11:14,092 E 8010 186068] core_worker_process.cc:825: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# 2026-02-11 12:11:15,287	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (train1 pid=8010) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00087_87_batch_size=16,conv_kernel_size=3,lr=0.0034,out_channels=32,pool_kernel_size=4_2026-02-11_11-06-08/checkpoint_000000)
# (raylet) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (raylet)   warnings.warn(
# (train1 pid=7969) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 6x across cluster]
# (train1 pid=7969)   warnings.warn( [repeated 6x across cluster]
# (train1 pid=7958) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00085_85_batch_size=32,conv_kernel_size=4,lr=0.0008,out_channels=16,pool_kernel_size=2_2026-02-11_11-06-08/checkpoint_000002)
# (train1 pid=7958) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 2x across cluster]
# (train1 pid=7958)   warnings.warn( [repeated 2x across cluster]
# 2026-02-11 12:11:34,423	WARNING experiment_state.py:206 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds and may become a bottleneck. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this warning by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0). Set it to 0 to completely suppress this warning.
# (train1 pid=7969) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00086_86_batch_size=16,conv_kernel_size=7,lr=0.0006,out_channels=16,pool_kernel_size=2_2026-02-11_11-06-08/checkpoint_000002)
# (train1 pid=7969) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (train1 pid=7969)   warnings.warn(
# (train1 pid=7969) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (train1 pid=7969)   warnings.warn(
# (train1 pid=8040) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 2x across cluster]
# (train1 pid=8040)   warnings.warn( [repeated 2x across cluster]
# (train1 pid=8040) [2026-02-11 12:11:48,665 E 8040 186738] core_worker_process.cc:825: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (train1 pid=7958) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 2x across cluster]
# (train1 pid=7958)   warnings.warn( [repeated 2x across cluster]
# (train1 pid=8040) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00088_88_batch_size=16,conv_kernel_size=4,lr=0.0248,out_channels=32,pool_kernel_size=4_2026-02-11_11-06-08/checkpoint_000000)
# (train1 pid=7969) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 2x across cluster]
# (train1 pid=7969)   warnings.warn( [repeated 2x across cluster]
# (train1 pid=8096) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 6x across cluster]
# (train1 pid=8096)   warnings.warn( [repeated 6x across cluster]
# (train1 pid=7958) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 3x across cluster]
# (train1 pid=7958)   warnings.warn( [repeated 3x across cluster]
# (train1 pid=8096) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 2x across cluster]
# (train1 pid=8096)   warnings.warn( [repeated 2x across cluster]
# (train1 pid=8096) [2026-02-11 12:12:27,643 E 8096 187437] core_worker_process.cc:825: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (train1 pid=7958) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020 [repeated 2x across cluster]
# (train1 pid=7958)   warnings.warn( [repeated 2x across cluster]
# (train1 pid=8096) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00089_89_batch_size=32,conv_kernel_size=7,lr=0.0128,out_channels=32,pool_kernel_size=4_2026-02-11_11-06-08/checkpoint_000000)
# (train1 pid=7958) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (train1 pid=7958)   warnings.warn(
# (train1 pid=7958) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (train1 pid=7958)   warnings.warn(
# (train1 pid=7958) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00085_85_batch_size=32,conv_kernel_size=4,lr=0.0008,out_channels=16,pool_kernel_size=2_2026-02-11_11-06-08/checkpoint_000003)
# (train1 pid=7958) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (train1 pid=7958)   warnings.warn(
# (train1 pid=7958) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (train1 pid=7958)   warnings.warn(
# (train1 pid=7958) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (train1 pid=7958)   warnings.warn(
# (train1 pid=7958) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (train1 pid=7958)   warnings.warn(
# (train1 pid=7958) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/Users/alessandro/ray_results/train1_2026-02-11_11-06-08/train1_4906e_00085_85_batch_size=32,conv_kernel_size=4,lr=0.0008,out_channels=16,pool_kernel_size=2_2026-02-11_11-06-08/checkpoint_000004)
# (train1 pid=7958) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (train1 pid=7958)   warnings.warn(
# (train1 pid=7958) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (train1 pid=7958)   warnings.warn(
# (train1 pid=7958) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (train1 pid=7958)   warnings.warn(
# (train1 pid=7958) /Users/alessandro/Progetti/RockPaperScissorNew/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
# (train1 pid=7958)   warnings.warn(
# 2026-02-11 12:13:47,511	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/alessandro/ray_results/train1_2026-02-11_11-06-08' in 0.0354s.
# 2026-02-11 12:13:47,525	INFO tune.py:1041 -- Total run time: 4059.01 seconds (4058.94 seconds for the tuning loop).

# %% [markdown]
# What happens:
#
# Ray coordinator spawns worker processes
#
# Workers run your train1() function with different configs
#
# Workers send metrics back via tune.report()
#
# Scheduler decides which trials to stop early
#
# When all trials finish, returns the results
#
# The script waits here until the entire search (potentially hours) completes.

# %%
best_result = result_grid.get_best_result(metric="loss", mode="min")
print("Best config:\n", best_result.config)
print("Best final metrics:\n", best_result.metrics)

# Per-epoch history for best trial
df_best = best_result.metrics_dataframe  # columns include: training_iteration, loss, accuracy, train_loss

plt.figure()
plt.plot(df_best["training_iteration"], df_best["loss"])
plt.xlabel("Epoch (training_iteration)")
plt.ylabel("Val loss")
plt.title("Best trial - validation loss")
plt.show()

plt.figure()
plt.plot(df_best["training_iteration"], df_best["accuracy"])
plt.xlabel("Epoch (training_iteration)")
plt.ylabel("Val accuracy")
plt.title("Best trial - validation accuracy")
plt.show()

# Summary table of final metrics across all trials
rows = []
for r in result_grid:
    rows.append({
        **r.config,
        "final_loss": r.metrics.get("loss"),
        "final_accuracy": r.metrics.get("accuracy"),
    })
df_all = pd.DataFrame(rows).sort_values("final_loss")
display(df_all.head(10))
# Out:
# Best config:
#  {'out_channels': 32, 'conv_kernel_size': 7, 'pool_kernel_size': 4, 'lr': 0.0007644457600399752, 'batch_size': 16}
# Best final metrics:
#  {'loss': 0.2784170227502387, 'accuracy': 0.9202453987730062, 'train_loss': 0.2727836067578436, 'timestamp': 1770808240, 'checkpoint_dir_name': None, 'done': True, 'training_iteration': 10, 'trial_id': '4906e_00080', 'date': '2026-02-11_12-10-40', 'time_this_iter_s': 35.892356872558594, 'time_total_s': 344.4742157459259, 'pid': 7686, 'hostname': 'Alessandros-MacBook-Air.local', 'node_ip': '127.0.0.1', 'config': {'out_channels': 32, 'conv_kernel_size': 7, 'pool_kernel_size': 4, 'lr': 0.0007644457600399752, 'batch_size': 16}, 'time_since_restore': 344.4742157459259, 'iterations_since_restore': 10, 'experiment_tag': '80_batch_size=16,conv_kernel_size=7,lr=0.0008,out_channels=32,pool_kernel_size=4'}
#     out_channels  conv_kernel_size  pool_kernel_size        lr  batch_size  \
# 80            32                 7                 4  0.000764          16
# 17            32                 7                 4  0.003632          32
# 68            16                 7                 2  0.000337          16
# 14            16                 7                 4  0.000232          16
# 59            16                 7                 2  0.000485          32
# 23            16                 7                 2  0.000111          16
# 13            16                 4                 2  0.000493          64
# 44            32                 7                 4  0.000540          64
# 7             32                 4                 2  0.000818          32
# 25            32                 4                 2  0.000395          64
#
#     final_loss  final_accuracy
# 80    0.278417        0.920245
# 17    0.290300        0.920245
# 68    0.362081        0.898773
# 14    0.422278        0.871166
# 59    0.434093        0.868098
# 23    0.446245        0.849693
# 13    0.454287        0.849693
# 44    0.470431        0.846626
# 7     0.471675        0.849693
# 25    0.474158        0.855828

# %%
TEST_DIR = "/Users/alessandro/Progetti/RockPaperScissorNew/rps-split/test"  


device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")


img_size = (256, 256)
test_transform = transforms.Compose([
    transforms.Resize(img_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
])

# Load test set
test_ds = datasets.ImageFolder(TEST_DIR, transform=test_transform)
print("Test classes:", test_ds.classes, "  n_test:", len(test_ds))

#Pick best trial + checkpoint from your existing ResultGrid
# use the ResultGrid variable from the tuning run
best_result = result_grid.get_best_result(metric="loss", mode="min")
best_config = best_result.config
best_ckpt = best_result.checkpoint

#  Rebuild model with best hyperparams
model = SimpleCNN(
    num_classes=len(test_ds.classes),
    out_channels=best_config["out_channels"],
    conv_kernel_size=best_config["conv_kernel_size"],
    pool_kernel_size=best_config["pool_kernel_size"],
).to(device)

# IMPORTANT: initialize LazyLinear by running a dummy forward once
with torch.no_grad():
    _ = model(torch.zeros(1, 3, img_size[0], img_size[1], device=device))

# Load weights from checkpoint (model.pt saved inside the checkpoint directory)
ckpt_dir = best_ckpt.to_directory() 
ckpt_path = os.path.join(ckpt_dir, "model.pt")

state = torch.load(ckpt_path, map_location=device)
model.load_state_dict(state["model_state"], strict=True)
model.eval()

# Dataloader 
test_loader = DataLoader( 
    test_ds,
    batch_size=int(best_config["batch_size"]),
    shuffle=False,
    num_workers=2,
)

# Evaluate
criterion = nn.CrossEntropyLoss()
total, correct, test_loss_sum = 0, 0, 0.0

all_preds = []
all_labels = []

with torch.no_grad():
    for x, y in test_loader: # x is the batch of input images, y is the batch of corresponding labels
        x, y = x.to(device), y.to(device)
        logits = model(x)
        loss = criterion(logits, y)

        bs = y.size(0) 
        test_loss_sum += loss.item() * bs 
        preds = logits.argmax(dim=1) # get predicted class indices by taking the argmax of the logits along the class dimension

        correct += (preds == y).sum().item()
        total += bs

        all_preds.append(preds.cpu())
        all_labels.append(y.cpu())

test_loss = test_loss_sum / max(total, 1)
test_acc = correct / max(total, 1)

print("\nBest config:", best_config)
print(f"Test loss: {test_loss:.4f}")
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Test classes: ['paper', 'rock', 'scissors']   n_test: 331
#
# Best config: {'out_channels': 32, 'conv_kernel_size': 7, 'pool_kernel_size': 4, 'lr': 0.0007644457600399752, 'batch_size': 16}
# Test loss: 0.2737
# Test accuracy: 0.9154

# %%
# Concatenate the tensors collected during evaluation - from lists of tensors to single tensors, then convert to numpy arrays for sklearn metrics
y_true = torch.cat(all_labels).numpy() 
y_pred = torch.cat(all_preds).numpy() 

# Confusion matrix (counts)
cm = confusion_matrix(y_true, y_pred)  # C[i, j] = # true=i predicted=j
print("Confusion matrix (counts):\n", cm)

# Normalized by true class (rows sum to 1)
cm_norm = confusion_matrix(y_true, y_pred, normalize="true")  # normalize='true' -> row-normalized 

# Plot (counts)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=test_ds.classes)
disp.plot(xticks_rotation=45)
plt.title("Confusion matrix (counts)")
plt.tight_layout()
plt.show()  # ConfusionMatrixDisplay is intended for plotting a confusion matrix 

# Plot (row-normalized)
disp_norm = ConfusionMatrixDisplay(confusion_matrix=cm_norm, display_labels=test_ds.classes)
disp_norm.plot(xticks_rotation=45, values_format=".2f")
plt.title("Confusion matrix (normalized by true class)")
plt.tight_layout()
plt.show()  # normalize option controls how entries are normalized 

# Classification report (precision/recall/F1 per class)
print("\nClassification report:")
print(classification_report(y_true, y_pred, target_names=test_ds.classes, digits=4))  # target_names labels classes
# Out:
# Confusion matrix (counts):
#  [[ 98   1   9]
#  [  2  95  13]
#  [  1   2 110]]
# Classification report:
#               precision    recall  f1-score   support
#
#        paper     0.9703    0.9074    0.9378       108
#         rock     0.9694    0.8636    0.9135       110
#     scissors     0.8333    0.9735    0.8980       113
#
#     accuracy                         0.9154       331
#    macro avg     0.9243    0.9148    0.9164       331
# weighted avg     0.9232    0.9154    0.9161       331
